# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Payam Zachkani**
#
# Data Scientist

# %% [markdown]
# *I am interested in data science because it can help pave the way towards personalized medicine. I would like to be a part of that journey.*

# %% [markdown]
# ### The code below returns a random integer between 1 and 10.

# %%
import random
random.randint(1,10)
# Out:
# 2

# %% [markdown]
# * item_1
# * item_2
# * item_3
#     * subItem_1
#
# | col_1 | col_2 | col_3 |
# | ----- | ----- | ----- |
# | val_1 | val_2 | val_3 |
#
# __[Coursera Website](https://www.coursera.org/)__
#
# 1. Num_1
# 2. Num_2
# 3. Num_3
